# %%
# Convolutional Neural Network (CNN) with the maxtrix of TF-IDF feature.

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import time

# Load data
df = pd.read_csv('./spam_or_not_spam.csv')
df['email'] = df['email'].fillna('')

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(df['email'], df['label'], test_size=0.2)

# Create TF-IDF vectorizer
vectorizer = TfidfVectorizer()

# Convert text data to TF-IDF matrix
tfidf_matrix_train = vectorizer.fit_transform(X_train)
tfidf_matrix_test = vectorizer.transform(X_test)

# Convert sparse data to NumPy arrays
X_train = tfidf_matrix_train.toarray()
X_test = tfidf_matrix_test.toarray().tolist()
X_test = np.array(X_test)

# Reshape the input data for convolutional layers
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1, 1)
X_test = X_test.reshape(X_test.shape[0], X_train.shape[1], 1, 1)

# Define Keras model
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 1), activation='relu', input_shape=X_train.shape[1:]))
model.add(MaxPooling2D(pool_size=(2, 1)))
model.add(Dropout(0.25))
model.add(Conv2D(64, kernel_size=(3, 1), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 1)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# Define learning rate
learning_rate = 0.01

# Define optimizer with specified learning rate
optimizer = Adam(learning_rate=learning_rate)

# Compile model
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Define early stopping callback
early_stopping = EarlyStopping(patience=5)

# Train model with validation split
start_time = time.time()
history = model.fit(X_train, y_train, epochs=15, batch_size=32, validation_split=0.2)
end_time = time.time()

# Evaluate model on test set
_, accuracy = model.evaluate(X_test, y_test)
y_pred = model.predict(X_test)
y_pred = np.round(y_pred)

from sklearn.metrics import classification_report, confusion_matrix
print('Test accuracy:', accuracy)
print('Process time for', len(history.history['loss']), 'epochs:', end_time - start_time, 'seconds')
print('Classification Report:\n', classification_report(y_test, y_pred))
print('Confusion Matrix:\n', confusion_matrix(y_test, y_pred))
# Out:
# Epoch 1/15
# 60/60 [==============================] - 72s 1s/step - loss: 0.3897 - accuracy: 0.8870 - val_loss: 0.0828 - val_accuracy: 0.9667
# Epoch 2/15
# 60/60 [==============================] - 70s 1s/step - loss: 0.0403 - accuracy: 0.9896 - val_loss: 0.0373 - val_accuracy: 0.9833
# Epoch 3/15
# 60/60 [==============================] - 71s 1s/step - loss: 0.0158 - accuracy: 0.9948 - val_loss: 0.0403 - val_accuracy: 0.9750
# Epoch 4/15
# 60/60 [==============================] - 73s 1s/step - loss: 0.0019 - accuracy: 0.9990 - val_loss: 0.0463 - val_accuracy: 0.9812
# Epoch 5/15
# 60/60 [==============================] - 71s 1s/step - loss: 0.0030 - accuracy: 0.9979 - val_loss: 0.0431 - val_accuracy: 0.9896
# Epoch 6/15
# 60/60 [==============================] - 70s 1s/step - loss: 0.0162 - accuracy: 0.9969 - val_loss: 0.0850 - val_accuracy: 0.9729
# Epoch 7/15
# 60/60 [==============================] - 71s 1s/step - loss: 0.0043 - accuracy: 0.9974 - val_loss: 0.0635 - val_accuracy: 0.9833
# Epoch 8/15
# 60/60 [==============================] - 69s 1s/step - loss: 0.0145 - accuracy: 0.9984 - val_loss: 0.0997 - val_accuracy: 0.9688
# Epoch 9/15
# 60/60 [==============================] - 67s 1s/step - loss: 0.0176 - accuracy: 0.9979 - val_loss: 0.0676 - val_accuracy: 0.9812
# Epoch 10/15
# 60/60 [==============================] - 70s 1s/step - loss: 0.0065 - accuracy: 0.9974 - val_loss: 0.0730 - val_accuracy: 0.9792
# Epoch 11/15
# 60/60 [==============================] - 70s 1s/step - loss: 0.0145 - accuracy: 0.9984 - val_loss: 0.0761 - val_accuracy: 0.9812
# Epoch 12/15
# 60/60 [==============================] - 67s 1s/step - loss: 0.0056 - accuracy: 0.9974 - val_loss: 0.0815 - val_accuracy: 0.9792
# Epoch 13/15
# 60/60 [==============================] - 68s 1s/step - loss: 0.0056 - accuracy: 0.9990 - val_loss: 0.1083 - val_accuracy: 0.9854
# Epoch 14/15
# 60/60 [==============================] - 70s 1s/step - loss: 0.0058 - accuracy: 0.9974 - val_loss: 0.1299 - val_accuracy: 0.9729
# Epoch 15/15
# 60/60 [==============================] - 71s 1s/step - loss: 0.0044 - accuracy: 0.9979 - val_loss: 0.1299 - val_accuracy: 0.9854
# 19/19 [==============================] - 3s 144ms/step - loss: 0.1423 - accuracy: 0.9817
# 19/19 [==============================] - 3s 131ms/step
# Test accuracy: 0.9816666841506958
# Process time for 15 epochs: 1048.7179567813873 seconds
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       502
#            1       0.97      0.92      0.94        98
#
#     accuracy                           0.98       600
#    macro avg       0.98      0.96      0.97       600
# weighted avg       0.98      0.98      0.98       600
#
# Confusion Matrix:
#  [[499   3]
#  [  8  90]]

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Spam Email Validation')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
# Feedforward Neural Network (CNN) with the maxtrix of TF-IDF feature.

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import time

# Load data
df = pd.read_csv('./spam_or_not_spam.csv')
df['email'] = df['email'].fillna('')

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(df['email'], df['label'], test_size=0.2)

# Create TF-IDF vectorizer
vectorizer = TfidfVectorizer()

# Convert text data to TF-IDF matrix
tfidf_matrix_train = vectorizer.fit_transform(X_train)
tfidf_matrix_test = vectorizer.transform(X_test)

# Convert sparse data to NumPy arrays
X_train = tfidf_matrix_train.toarray()
X_test = tfidf_matrix_test.toarray()

# Define Keras model
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# Define learning rate
learning_rate = 0.01

# Define optimizer with specified learning rate
optimizer = Adam(learning_rate=learning_rate)

# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Define early stopping callback
early_stopping = EarlyStopping(patience=5)

# Train model with validation split
start_time = time.time()
history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)
end_time = time.time()

# Evaluate model on test set
_, accuracy = model.evaluate(X_test, y_test)
y_pred = model.predict(X_test)
y_pred = np.round(y_pred)

from sklearn.metrics import classification_report, confusion_matrix
print('Test accuracy:', accuracy)
print('Process time for', len(history.history['loss']), 'epochs:', end_time - start_time, 'seconds')
print('Classification Report:\n', classification_report(y_test, y_pred))
print('Confusion Matrix:\n', confusion_matrix(y_test, y_pred))
# Out:
# Epoch 1/10
# 60/60 [==============================] - 2s 33ms/step - loss: 0.4605 - accuracy: 0.8406 - val_loss: 0.3243 - val_accuracy: 0.8375
# Epoch 2/10
# 60/60 [==============================] - 2s 32ms/step - loss: 0.1877 - accuracy: 0.9365 - val_loss: 0.1411 - val_accuracy: 0.9729
# Epoch 3/10
# 60/60 [==============================] - 2s 31ms/step - loss: 0.0719 - accuracy: 0.9906 - val_loss: 0.0756 - val_accuracy: 0.9833
# Epoch 4/10
# 60/60 [==============================] - 2s 32ms/step - loss: 0.0321 - accuracy: 0.9984 - val_loss: 0.0556 - val_accuracy: 0.9833
# Epoch 5/10
# 60/60 [==============================] - 2s 34ms/step - loss: 0.0179 - accuracy: 0.9990 - val_loss: 0.0467 - val_accuracy: 0.9833
# Epoch 6/10
# 60/60 [==============================] - 2s 32ms/step - loss: 0.0121 - accuracy: 0.9990 - val_loss: 0.0427 - val_accuracy: 0.9833
# Epoch 7/10
# 60/60 [==============================] - 2s 32ms/step - loss: 0.0081 - accuracy: 0.9990 - val_loss: 0.0396 - val_accuracy: 0.9833
# Epoch 8/10
# 60/60 [==============================] - 2s 32ms/step - loss: 0.0061 - accuracy: 0.9990 - val_loss: 0.0382 - val_accuracy: 0.9833
# Epoch 9/10
# 60/60 [==============================] - 2s 35ms/step - loss: 0.0047 - accuracy: 0.9995 - val_loss: 0.0372 - val_accuracy: 0.9833
# Epoch 10/10
# 60/60 [==============================] - 2s 31ms/step - loss: 0.0040 - accuracy: 0.9995 - val_loss: 0.0364 - val_accuracy: 0.9833
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0624 - accuracy: 0.9783
# 19/19 [==============================] - 0s 3ms/step
# Test accuracy: 0.9783333539962769
# Process time for 10 epochs: 19.888880968093872 seconds
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       490
#            1       1.00      0.88      0.94       110
#
#     accuracy                           0.98       600
#    macro avg       0.99      0.94      0.96       600
# weighted avg       0.98      0.98      0.98       600
#
# Confusion Matrix:
#  [[490   0]
#  [ 13  97]]

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Spam Email Validation')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()
